# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from comp411.classifiers.neural_net import FourLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `FourLayerNet` in the file `comp411/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return FourLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `comp411/classifiers/neural_net.py` and look at the method `FourLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')

correct_scores = np.asarray([
 [ 0.00061941, -0.00199624,  0.00122278],
 [-0.05414592, 0.0001925, -0.00444115],
 [-0.04353788, -0.0003643, 0.00332125],
 [-0.03731218, 0.00280601, 0.00089339],
 [ 0.00125563, 0.00055453, -0.00509995]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[ 0.00061941 -0.00199624  0.00122278]
#  [-0.05414592  0.0001925  -0.00444115]
#  [-0.04353788 -0.0003643   0.00332125]
#  [-0.03731218  0.00280601  0.00089339]
#  [ 0.00125563  0.00055453 -0.00509995]]
#
# correct scores:
# [[ 0.00061941 -0.00199624  0.00122278]
#  [-0.05414592  0.0001925  -0.00444115]
#  [-0.04353788 -0.0003643   0.00332125]
#  [-0.03731218  0.00280601  0.00089339]
#  [ 0.00125563  0.00055453 -0.00509995]]
#
# Difference between your scores and correct scores:
# 4.092880420228395e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularization loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.2193239054381837


# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 0.0

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, `b2`, `W3` , `b3` , `W4` and `b4`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from comp411.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, W3, W4, b1, b2, b3 and b4.
regp = 0.5
loss, grads = net.loss(X, y, reg=regp)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=regp)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W4 max relative error: 4.937505e-10
# b4 max relative error: 1.038545e-10
# W3 max relative error: 1.284769e-08
# b3 max relative error: 3.943774e-09
# W2 max relative error: 1.486289e-08
# b2 max relative error: 9.565364e-09
# W1 max relative error: 6.851620e-09
# b1 max relative error: 2.546078e-07

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `FourLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `FourLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a four-layer network on toy data. You should achieve a training loss less than 0.20.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=4e-1, reg=5e-7,
            num_iters=200, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.19588526787218707

# %% [markdown]
# # Load the data
# Now that you have implemented a three-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from comp411.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the three-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'comp411/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
np.random.seed(1)
input_size = 32 * 32 * 3
hidden_size = 10
num_classes = 10
net = FourLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=2000, batch_size=200,
            learning_rate= 2e-2, learning_rate_decay=0.95,
            reg= 5e-6, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 2000: loss 2.302621
# iteration 100 / 2000: loss 2.302299
# iteration 200 / 2000: loss 2.302835
# iteration 300 / 2000: loss 2.302133
# iteration 400 / 2000: loss 2.302784
# iteration 500 / 2000: loss 2.300194
# iteration 600 / 2000: loss 2.191088
# iteration 700 / 2000: loss 2.141923
# iteration 800 / 2000: loss 2.186701
# iteration 900 / 2000: loss 2.050699
# iteration 1000 / 2000: loss 2.081283
# iteration 1100 / 2000: loss 2.034286
# iteration 1200 / 2000: loss 1.901898
# iteration 1300 / 2000: loss 1.862809
# iteration 1400 / 2000: loss 1.873545
# iteration 1500 / 2000: loss 1.795497
# iteration 1600 / 2000: loss 1.732206
# iteration 1700 / 2000: loss 1.809687
# iteration 1800 / 2000: loss 1.781071
# iteration 1900 / 2000: loss 1.715776
# Validation accuracy:  0.344

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.344 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()

# %%
from comp411.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can (48% could serve as a reference), with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).
#
# **Best results amongst the class will receive bonus points!!!**

# %% [markdown]
# **Explain your hyperparameter tuning process below.**
#
# $\color{blue}{\textit Your Answer:}$ We put all the hyper parameters in lists to try, here with the help of itertools.product, we do cartesian product of these lists and take the corresponding parameter from these lists, for every combination, we train the network from scratch and look at the validation losses. In these lists, we put values that might give better results such as bigger networks, different learning rates, different batch sizes as all these may affect the end result. We ran these with different lists and for it not to take too much time if someone else runs this, we cut some of the least accurate combinations (ie. very low lr, big regularization etc.)

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
lr_list = [1e-1, 1e-3]
reg_list = [5e-6, 1e-5]
num_iters_list = [2000, 3000]
hidden_size_list = [256, 512]

results = {}
best_score = -np.inf
best_param = {}
from itertools import product
for lr, reg, num_iter, hidden in product(lr_list, reg_list, num_iters_list, hidden_size_list):
    net = FourLayerNet(input_size, hidden, num_classes)
    stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=num_iter,
            learning_rate= lr, learning_rate_decay=0.9,
            reg=reg, batch_size=400, verbose=True)

    train_acc = (net.predict(X_train) == y_train).mean()
    valid_acc = (net.predict(X_val) == y_val).mean()
    print('Validation accuracy: ', valid_acc)
    results[(lr, reg, num_iter, hidden)] = (train_acc, valid_acc)

    if valid_acc > best_score:
        best_score = valid_acc
        best_param = {'learning_rate':lr, 'reg':reg, 'num_iters':num_iter, 'hidden_size':hidden}
        best_net = net

for lr, reg, num_iter, hidden in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg, num_iter, hidden)]
    print('lr %e reg %e num_iter %e hidden %e train accuracy: %f val accuracy: %f' % (
                lr, reg, num_iter, hidden, train_accuracy, val_accuracy))
print("Best parameters: ", best_param)
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# iteration 0 / 2000: loss 2.306145
# iteration 100 / 2000: loss 1.751166
# iteration 200 / 2000: loss 1.752552
# iteration 300 / 2000: loss 1.562453
# iteration 400 / 2000: loss 1.498092
# iteration 500 / 2000: loss 1.422061
# iteration 600 / 2000: loss 1.352646
# iteration 700 / 2000: loss 1.251203
# iteration 800 / 2000: loss 1.237640
# iteration 900 / 2000: loss 1.100403
# iteration 1000 / 2000: loss 0.985667
# iteration 1100 / 2000: loss 1.018895
# iteration 1200 / 2000: loss 0.863116
# iteration 1300 / 2000: loss 1.018588
# iteration 1400 / 2000: loss 0.930723
# iteration 1500 / 2000: loss 0.911318
# iteration 1600 / 2000: loss 0.864214
# iteration 1700 / 2000: loss 0.585119
# iteration 1800 / 2000: loss 0.688587
# iteration 1900 / 2000: loss 0.691999
# Validation accuracy:  0.526
# iteration 0 / 2000: loss 2.300581
# iteration 100 / 2000: loss 1.796770
# iteration 200 / 2000: loss 1.776670
# iteration 300 / 2000: loss 1.457195
# iteration 400 / 2000: loss 1.261700
# iteration 500 / 2000: loss 1.229474
# iteration 600 / 2000: loss 1.371971
# iteration 700 / 2000: loss 1.179273
# iteration 800 / 2000: loss 1.027061
# iteration 900 / 2000: loss 0.985754
# iteration 1000 / 2000: loss 0.902726
# iteration 1100 / 2000: loss 0.961409
# iteration 1200 / 2000: loss 0.722965
# iteration 1300 / 2000: loss 0.662813
# iteration 1400 / 2000: loss 0.619460
# iteration 1500 / 2000: loss 0.515909
# iteration 1600 / 2000: loss 0.523330
# iteration 1700 / 2000: loss 0.546469
# iteration 1800 / 2000: loss 0.262344
# iteration 1900 / 2000: loss 0.309005
# Validation accuracy:  0.549
# iteration 0 / 3000: loss 2.302921
# iteration 100 / 3000: loss 1.612888
# iteration 200 / 3000: loss 1.744446
# iteration 300 / 3000: loss 1.408753
# iteration 400 / 3000: loss 1.503859
# iteration 500 / 3000: loss 1.316028
# iteration 600 / 3000: loss 1.332134
# iteration 700 / 3000: loss 1.418399
# iteration 800 / 3000: loss 1.223481
# iteration 900 / 3000: loss 1.063178
# iteration 1000 / 3000: loss 1.029775
# iteration 1100 / 3000: loss 0.973127
# iteration 1200 / 3000: loss 0.894209
# iteration 1300 / 3000: loss 0.787287
# iteration 1400 / 3000: loss 0.862056
# iteration 1500 / 3000: loss 0.902295
# iteration 1600 / 3000: loss 0.880201
# iteration 1700 / 3000: loss 0.654762
# iteration 1800 / 3000: loss 0.611263
# iteration 1900 / 3000: loss 0.619178
# iteration 2000 / 3000: loss 0.560865
# iteration 2100 / 3000: loss 0.496170
# iteration 2200 / 3000: loss 0.626564
# iteration 2300 / 3000: loss 0.457697
# iteration 2400 / 3000: loss 0.379624
# iteration 2500 / 3000: loss 0.412082
# iteration 2600 / 3000: loss 0.353292
# iteration 2700 / 3000: loss 0.333984
# iteration 2800 / 3000: loss 0.229037
# iteration 2900 / 3000: loss 0.308148
# Validation accuracy:  0.54
# iteration 0 / 3000: loss 2.317600
# iteration 100 / 3000: loss 1.791277
# iteration 200 / 3000: loss 1.483070
# iteration 300 / 3000: loss 1.449859
# iteration 400 / 3000: loss 1.287714
# iteration 500 / 3000: loss 1.154094
# iteration 600 / 3000: loss 1.227142
# iteration 700 / 3000: loss 1.091943
# iteration 800 / 3000: loss 0.971648
# iteration 900 / 3000: loss 1.041454
# iteration 1000 / 3000: loss 0.878634
# iteration 1100 / 3000: loss 0.806519
# iteration 1200 / 3000: loss 0.710588
# iteration 1300 / 3000: loss 0.606271
# iteration 1400 / 3000: loss 0.609100
# iteration 1500 / 3000: loss 0.507465
# iteration 1600 / 3000: loss 0.491737
# iteration 1700 / 3000: loss 0.420184
# iteration 1800 / 3000: loss 0.267716
# iteration 1900 / 3000: loss 0.274168
# iteration 2000 / 3000: loss 0.201670
# iteration 2100 / 3000: loss 0.172957
# iteration 2200 / 3000: loss 0.175044
# iteration 2300 / 3000: loss 0.107084
# iteration 2400 / 3000: loss 0.099028
# iteration 2500 / 3000: loss 0.063916
# iteration 2600 / 3000: loss 0.043926
# iteration 2700 / 3000: loss 0.033598
# iteration 2800 / 3000: loss 0.017672
# iteration 2900 / 3000: loss 0.020414
# Validation accuracy:  0.576
# iteration 0 / 2000: loss 2.309755
# iteration 100 / 2000: loss 1.837577
# iteration 200 / 2000: loss 1.658740
# iteration 300 / 2000: loss 1.460887
# iteration 400 / 2000: loss 1.441454
# iteration 500 / 2000: loss 1.355364
# iteration 600 / 2000: loss 1.250283
# iteration 700 / 2000: loss 1.182279
# iteration 800 / 2000: loss 1.166079
# iteration 900 / 2000: loss 1.136469
# iteration 1000 / 2000: loss 1.048413
# iteration 1100 / 2000: loss 1.135495
# iteration 1200 / 2000: loss 0.964330
# iteration 1300 / 2000: loss 0.817014
# iteration 1400 / 2000: loss 0.803384
# iteration 1500 / 2000: loss 0.753586
# iteration 1600 / 2000: loss 0.825447
# iteration 1700 / 2000: loss 0.697556
# iteration 1800 / 2000: loss 0.640856
# iteration 1900 / 2000: loss 0.631858
# Validation accuracy:  0.553
# iteration 0 / 2000: loss 2.318673
# iteration 100 / 2000: loss 1.718385
# iteration 200 / 2000: loss 1.608416
# iteration 300 / 2000: loss 1.578442
# iteration 400 / 2000: loss 1.373017
# iteration 500 / 2000: loss 1.239695
# iteration 600 / 2000: loss 1.220182
# iteration 700 / 2000: loss 1.169723
# iteration 800 / 2000: loss 1.043255
# iteration 900 / 2000: loss 0.832431
# iteration 1000 / 2000: loss 0.814781
# iteration 1100 / 2000: loss 0.804970
# iteration 1200 / 2000: loss 0.748648
# iteration 1300 / 2000: loss 0.642850
# iteration 1400 / 2000: loss 0.584027
# iteration 1500 / 2000: loss 0.469808
# iteration 1600 / 2000: loss 0.462301
# iteration 1700 / 2000: loss 0.464466
# iteration 1800 / 2000: loss 0.330904
# iteration 1900 / 2000: loss 0.213535
# Validation accuracy:  0.548
# iteration 0 / 3000: loss 2.303541
# iteration 100 / 3000: loss 1.953681
# iteration 200 / 3000: loss 1.602330
# iteration 300 / 3000: loss 1.536737
# iteration 400 / 3000: loss 1.394295
# iteration 500 / 3000: loss 1.356831
# iteration 600 / 3000: loss 1.318226
# iteration 700 / 3000: loss 1.285991
# iteration 800 / 3000: loss 1.119954
# iteration 900 / 3000: loss 1.213077
# iteration 1000 / 3000: loss 1.054052
# iteration 1100 / 3000: loss 0.937556
# iteration 1200 / 3000: loss 0.937357
# iteration 1300 / 3000: loss 1.034944
# iteration 1400 / 3000: loss 0.925726
# iteration 1500 / 3000: loss 0.803100
# iteration 1600 / 3000: loss 0.864093
# iteration 1700 / 3000: loss 0.698929
# iteration 1800 / 3000: loss 0.675174
# iteration 1900 / 3000: loss 0.720780
# iteration 2000 / 3000: loss 0.701006
# iteration 2100 / 3000: loss 0.522195
# iteration 2200 / 3000: loss 0.512550
# iteration 2300 / 3000: loss 0.352020
# iteration 2400 / 3000: loss 0.448229
# iteration 2500 / 3000: loss 0.356704
# iteration 2600 / 3000: loss 0.323392
# iteration 2700 / 3000: loss 0.265616
# iteration 2800 / 3000: loss 0.262528
# iteration 2900 / 3000: loss 0.273772
# Validation accuracy:  0.528
# iteration 0 / 3000: loss 2.315092
# iteration 100 / 3000: loss 1.805944
# iteration 200 / 3000: loss 1.564942
# iteration 300 / 3000: loss 1.341765
# iteration 400 / 3000: loss 1.235012
# iteration 500 / 3000: loss 1.208006
# iteration 600 / 3000: loss 1.246620
# iteration 700 / 3000: loss 1.132888
# iteration 800 / 3000: loss 0.996670
# iteration 900 / 3000: loss 0.971662
# iteration 1000 / 3000: loss 0.824865
# iteration 1100 / 3000: loss 0.820752
# iteration 1200 / 3000: loss 0.683128
# iteration 1300 / 3000: loss 0.840519
# iteration 1400 / 3000: loss 0.597398
# iteration 1500 / 3000: loss 0.511113
# iteration 1600 / 3000: loss 0.462423
# iteration 1700 / 3000: loss 0.500164
# iteration 1800 / 3000: loss 0.305964
# iteration 1900 / 3000: loss 0.383832
# iteration 2000 / 3000: loss 0.207199
# iteration 2100 / 3000: loss 0.182439
# iteration 2200 / 3000: loss 0.192686
# iteration 2300 / 3000: loss 0.145045
# iteration 2400 / 3000: loss 0.070365
# iteration 2500 / 3000: loss 0.065146
# iteration 2600 / 3000: loss 0.034498
# iteration 2700 / 3000: loss 0.033181
# iteration 2800 / 3000: loss 0.025219
# iteration 2900 / 3000: loss 0.022731
# Validation accuracy:  0.551
# iteration 0 / 2000: loss 2.299024
# iteration 100 / 2000: loss 2.281759
# iteration 200 / 2000: loss 2.241778
# iteration 300 / 2000: loss 2.209474
# iteration 400 / 2000: loss 2.126933
# iteration 500 / 2000: loss 2.032185
# iteration 600 / 2000: loss 2.051588
# iteration 700 / 2000: loss 2.002050
# iteration 800 / 2000: loss 1.997121
# iteration 900 / 2000: loss 1.971786
# iteration 1000 / 2000: loss 1.988310
# iteration 1100 / 2000: loss 1.883603
# iteration 1200 / 2000: loss 1.929642
# iteration 1300 / 2000: loss 1.856367
# iteration 1400 / 2000: loss 1.864222
# iteration 1500 / 2000: loss 1.824104
# iteration 1600 / 2000: loss 1.875251
# iteration 1700 / 2000: loss 1.796310
# iteration 1800 / 2000: loss 1.819258
# iteration 1900 / 2000: loss 1.781933
# Validation accuracy:  0.379
# iteration 0 / 2000: loss 2.323447
# iteration 100 / 2000: loss 2.170216
# iteration 200 / 2000: loss 2.034731
# iteration 300 / 2000: loss 2.022580
# iteration 400 / 2000: loss 1.950715
# iteration 500 / 2000: loss 1.880495
# iteration 600 / 2000: loss 1.797330
# iteration 700 / 2000: loss 1.829817
# iteration 800 / 2000: loss 1.795675
# iteration 900 / 2000: loss 1.801614
# iteration 1000 / 2000: loss 1.697083
# iteration 1100 / 2000: loss 1.628440
# iteration 1200 / 2000: loss 1.686438
# iteration 1300 / 2000: loss 1.695702
# iteration 1400 / 2000: loss 1.753560
# iteration 1500 / 2000: loss 1.725416
# iteration 1600 / 2000: loss 1.630186
# iteration 1700 / 2000: loss 1.631600
# iteration 1800 / 2000: loss 1.689807
# iteration 1900 / 2000: loss 1.596437
# Validation accuracy:  0.435
# iteration 0 / 3000: loss 2.300521
# iteration 100 / 3000: loss 2.279338
# iteration 200 / 3000: loss 2.246001
# iteration 300 / 3000: loss 2.197441
# iteration 400 / 3000: loss 2.153775
# iteration 500 / 3000: loss 2.104832
# iteration 600 / 3000: loss 2.049151
# iteration 700 / 3000: loss 2.042536
# iteration 800 / 3000: loss 1.973346
# iteration 900 / 3000: loss 1.890454
# iteration 1000 / 3000: loss 1.956133
# iteration 1100 / 3000: loss 1.883036
# iteration 1200 / 3000: loss 1.952091
# iteration 1300 / 3000: loss 1.954568
# iteration 1400 / 3000: loss 1.817492
# iteration 1500 / 3000: loss 1.882876
# iteration 1600 / 3000: loss 1.841995
# iteration 1700 / 3000: loss 1.857357
# iteration 1800 / 3000: loss 1.854621
# iteration 1900 / 3000: loss 1.813805
# iteration 2000 / 3000: loss 1.885298
# iteration 2100 / 3000: loss 1.776749
# iteration 2200 / 3000: loss 1.826589
# iteration 2300 / 3000: loss 1.749577
# iteration 2400 / 3000: loss 1.787178
# iteration 2500 / 3000: loss 1.823273
# iteration 2600 / 3000: loss 1.722609
# iteration 2700 / 3000: loss 1.794905
# iteration 2800 / 3000: loss 1.801253
# iteration 2900 / 3000: loss 1.718327
# Validation accuracy:  0.394
# iteration 0 / 3000: loss 2.300820
# iteration 100 / 3000: loss 2.157536
# iteration 200 / 3000: loss 2.062185
# iteration 300 / 3000: loss 1.982938
# iteration 400 / 3000: loss 1.918493
# iteration 500 / 3000: loss 1.900726
# iteration 600 / 3000: loss 1.876177
# iteration 700 / 3000: loss 1.837308
# iteration 800 / 3000: loss 1.839527
# iteration 900 / 3000: loss 1.731722
# iteration 1000 / 3000: loss 1.776278
# iteration 1100 / 3000: loss 1.715691
# iteration 1200 / 3000: loss 1.723659
# iteration 1300 / 3000: loss 1.711435
# iteration 1400 / 3000: loss 1.677459
# iteration 1500 / 3000: loss 1.680460
# iteration 1600 / 3000: loss 1.647018
# iteration 1700 / 3000: loss 1.629222
# iteration 1800 / 3000: loss 1.705376
# iteration 1900 / 3000: loss 1.646863
# iteration 2000 / 3000: loss 1.732415
# iteration 2100 / 3000: loss 1.706775
# iteration 2200 / 3000: loss 1.548172
# iteration 2300 / 3000: loss 1.528861
# iteration 2400 / 3000: loss 1.684413
# iteration 2500 / 3000: loss 1.625660
# iteration 2600 / 3000: loss 1.581603
# iteration 2700 / 3000: loss 1.604758
# iteration 2800 / 3000: loss 1.606318
# iteration 2900 / 3000: loss 1.452333
# Validation accuracy:  0.449
# iteration 0 / 2000: loss 2.304279
# iteration 100 / 2000: loss 2.285552
# iteration 200 / 2000: loss 2.265909
# iteration 300 / 2000: loss 2.229803
# iteration 400 / 2000: loss 2.170622
# iteration 500 / 2000: loss 2.134611
# iteration 600 / 2000: loss 2.029576
# iteration 700 / 2000: loss 2.030133
# iteration 800 / 2000: loss 2.068774
# iteration 900 / 2000: loss 1.957086
# iteration 1000 / 2000: loss 1.976822
# iteration 1100 / 2000: loss 1.884772
# iteration 1200 / 2000: loss 1.873835
# iteration 1300 / 2000: loss 1.839128
# iteration 1400 / 2000: loss 1.824378
# iteration 1500 / 2000: loss 1.854222
# iteration 1600 / 2000: loss 1.815659
# iteration 1700 / 2000: loss 1.826390
# iteration 1800 / 2000: loss 1.776285
# iteration 1900 / 2000: loss 1.848461
# Validation accuracy:  0.37
# iteration 0 / 2000: loss 2.310665
# iteration 100 / 2000: loss 2.198874
# iteration 200 / 2000: loss 2.038711
# iteration 300 / 2000: loss 2.013533
# iteration 400 / 2000: loss 1.984411
# iteration 500 / 2000: loss 1.858085
# iteration 600 / 2000: loss 1.824574
# iteration 700 / 2000: loss 1.839156
# iteration 800 / 2000: loss 1.807884
# iteration 900 / 2000: loss 1.834919
# iteration 1000 / 2000: loss 1.795367
# iteration 1100 / 2000: loss 1.658570
# iteration 1200 / 2000: loss 1.713305
# iteration 1300 / 2000: loss 1.679827
# iteration 1400 / 2000: loss 1.646255
# iteration 1500 / 2000: loss 1.699532
# iteration 1600 / 2000: loss 1.666721
# iteration 1700 / 2000: loss 1.711965
# iteration 1800 / 2000: loss 1.611730
# iteration 1900 / 2000: loss 1.631518
# Validation accuracy:  0.438
# iteration 0 / 3000: loss 2.305888
# iteration 100 / 3000: loss 2.287086
# iteration 200 / 3000: loss 2.269211
# iteration 300 / 3000: loss 2.240198
# iteration 400 / 3000: loss 2.211315
# iteration 500 / 3000: loss 2.147877
# iteration 600 / 3000: loss 2.105898
# iteration 700 / 3000: loss 2.049461
# iteration 800 / 3000: loss 1.974842
# iteration 900 / 3000: loss 1.959941
# iteration 1000 / 3000: loss 1.970635
# iteration 1100 / 3000: loss 1.938210
# iteration 1200 / 3000: loss 1.929497
# iteration 1300 / 3000: loss 1.928415
# iteration 1400 / 3000: loss 1.813883
# iteration 1500 / 3000: loss 1.833505
# iteration 1600 / 3000: loss 1.853094
# iteration 1700 / 3000: loss 1.792024
# iteration 1800 / 3000: loss 1.829928
# iteration 1900 / 3000: loss 1.790778
# iteration 2000 / 3000: loss 1.789186
# iteration 2100 / 3000: loss 1.868920
# iteration 2200 / 3000: loss 1.758402
# iteration 2300 / 3000: loss 1.832362
# iteration 2400 / 3000: loss 1.799304
# iteration 2500 / 3000: loss 1.748310
# iteration 2600 / 3000: loss 1.764753
# iteration 2700 / 3000: loss 1.779274
# iteration 2800 / 3000: loss 1.780911
# iteration 2900 / 3000: loss 1.763313
# Validation accuracy:  0.384
# iteration 0 / 3000: loss 2.319394
# iteration 100 / 3000: loss 2.186184
# iteration 200 / 3000: loss 2.035872
# iteration 300 / 3000: loss 1.922237
# iteration 400 / 3000: loss 1.951094
# iteration 500 / 3000: loss 1.849746
# iteration 600 / 3000: loss 1.784308
# iteration 700 / 3000: loss 1.816538
# iteration 800 / 3000: loss 1.761891
# iteration 900 / 3000: loss 1.818058
# iteration 1000 / 3000: loss 1.676538
# iteration 1100 / 3000: loss 1.700635
# iteration 1200 / 3000: loss 1.698668
# iteration 1300 / 3000: loss 1.693448
# iteration 1400 / 3000: loss 1.689174
# iteration 1500 / 3000: loss 1.607545
# iteration 1600 / 3000: loss 1.616643
# iteration 1700 / 3000: loss 1.622213
# iteration 1800 / 3000: loss 1.619234
# iteration 1900 / 3000: loss 1.647683
# iteration 2000 / 3000: loss 1.623828
# iteration 2100 / 3000: loss 1.614846
# iteration 2200 / 3000: loss 1.635987
# iteration 2300 / 3000: loss 1.576630
# iteration 2400 / 3000: loss 1.522212
# iteration 2500 / 3000: loss 1.578696
# iteration 2600 / 3000: loss 1.627589
# iteration 2700 / 3000: loss 1.560340
# iteration 2800 / 3000: loss 1.580934
# iteration 2900 / 3000: loss 1.470874
# Validation accuracy:  0.445
# lr 1.000000e-03 reg 5.000000e-06 num_iter 2.000000e+03 hidden 2.560000e+02 train accuracy: 0.361388 val accuracy: 0.379000
# lr 1.000000e-03 reg 5.000000e-06 num_iter 2.000000e+03 hidden 5.120000e+02 train accuracy: 0.429408 val accuracy: 0.435000
# lr 1.000000e-03 reg 5.000000e-06 num_iter 3.000000e+03 hidden 2.560000e+02 train accuracy: 0.384776 val accuracy: 0.394000
# lr 1.000000e-03 reg 5.000000e-06 num_iter 3.000000e+03 hidden 5.120000e+02 train accuracy: 0.447429 val accuracy: 0.449000
# lr 1.000000e-03 reg 1.000000e-05 num_iter 2.000000e+03 hidden 2.560000e+02 train accuracy: 0.359857 val accuracy: 0.370000
# lr 1.000000e-03 reg 1.000000e-05 num_iter 2.000000e+03 hidden 5.120000e+02 train accuracy: 0.425571 val accuracy: 0.438000
# lr 1.000000e-03 reg 1.000000e-05 num_iter 3.000000e+03 hidden 2.560000e+02 train accuracy: 0.377122 val accuracy: 0.384000
# lr 1.000000e-03 reg 1.000000e-05 num_iter 3.000000e+03 hidden 5.120000e+02 train accuracy: 0.453449 val accuracy: 0.445000
# lr 1.000000e-01 reg 5.000000e-06 num_iter 2.000000e+03 hidden 2.560000e+02 train accuracy: 0.784735 val accuracy: 0.526000
# lr 1.000000e-01 reg 5.000000e-06 num_iter 2.000000e+03 hidden 5.120000e+02 train accuracy: 0.924082 val accuracy: 0.549000
# lr 1.000000e-01 reg 5.000000e-06 num_iter 3.000000e+03 hidden 2.560000e+02 train accuracy: 0.937796 val accuracy: 0.540000
# lr 1.000000e-01 reg 5.000000e-06 num_iter 3.000000e+03 hidden 5.120000e+02 train accuracy: 0.999102 val accuracy: 0.576000
# lr 1.000000e-01 reg 1.000000e-05 num_iter 2.000000e+03 hidden 2.560000e+02 train accuracy: 0.818367 val accuracy: 0.553000
# lr 1.000000e-01 reg 1.000000e-05 num_iter 2.000000e+03 hidden 5.120000e+02 train accuracy: 0.929735 val accuracy: 0.548000
# lr 1.000000e-01 reg 1.000000e-05 num_iter 3.000000e+03 hidden 2.560000e+02 train accuracy: 0.937959 val accuracy: 0.528000
# lr 1.000000e-01 reg 1.000000e-05 num_iter 3.000000e+03 hidden 5.120000e+02 train accuracy: 0.998714 val accuracy: 0.551000
# Best parameters:  {'learning_rate': 0.1, 'reg': 5e-06, 'num_iters': 3000, 'hidden_size': 512}

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.56

# %% [markdown]
# **Inline Question**
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
#
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# $\color{blue}{\textit Your Answer:}$ 1, 3
#
#
# $\color{blue}{\textit Your Explanation:}$
# 1- If we have larget dataset, nn will learn more features and representations, thus it might perform better on test and not overfit to train.
# 2- If we have more hidden units, meaning more complex learning function, model might overfit to training data and thus, test accuracy might decrease while training is increasing.
# 3- If we regularize the weights, classifier won't overfit and we will have more robust model, simpler algorithm will have closer test accuracy.
